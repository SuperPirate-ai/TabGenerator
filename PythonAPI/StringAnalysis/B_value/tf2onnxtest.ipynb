# %%
import tf2onnx.convert as conv
from sbNative.debugtools import log
import tensorflow as tf
import os
from os import path

# %%
model_path = path.join(os.getcwd(),"src","models","model_with_frets_and_strings.h5")
model = tf.keras.models.load_model(model_path)
model.output_names=['output']
input_signature = [tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype, name='digit')]


conv.from_keras(model, input_signature=input_signature, opset=13, output_path='model_with_frets_and_strings.onnx')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ERROR:tf2onnx.tfonnx:rewriter <function rewrite_constant_fold at 0x000001E264391C60>: exception `np.cast` was removed in the NumPy 2.0 release. Use `np.asarray(arr, dtype=dtype)` instead.
# (ir_version: 7
#  producer_name: "tf2onnx"
#  producer_version: "1.16.1 15c810"
#  graph {
#    node {
#      input: "digit"
#      input: "sequential_16_1/normalization_14_1/Sub/y:0"
#      output: "sequential_16_1/normalization_14_1/Sub:0"
#      name: "sequential_16_1/normalization_14_1/Sub"
#      op_type: "Sub"
#    }
#    node {
#      input: "sequential_16_1/normalization_14_1/Sub:0"
#      input: "ConstantFolding/sequential_16_1/normalization_14_1/truediv_recip:0"
#      output: "sequential_16_1/normalization_14_1/truediv:0"
#      name: "sequential_16_1/normalization_14_1/truediv"
#      op_type: "Mul"
#    }
#    node {
#      input: "sequential_16_1/normalization_14_1/truediv:0"
#      input: "sequential_16_1/dense_64_1/Cast/ReadVariableOp:0"
#      output: "sequential_16_1/dense_64_1/MatMul:0"
#      name: "sequential_16_1/dense_64_1/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential_16_1/dense_64_1/MatMul:0"
#      input: "sequential_16_1/dense_64_1/BiasAdd/ReadVariableOp:0"
#      output: "sequential_16_1/dense_64_1/BiasAdd:0"
#      name: "sequential_16_1/dense_64_1/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential_16_1/dense_64_1/BiasAdd:0"
#      output: "sequential_16_1/dense_64_1/Tanh:0"
#      name: "sequential_16_1/dense_64_1/Tanh"
#      op_type: "Tanh"
#    }
#    node {
#      input: "sequential_16_1/dense_64_1/Tanh:0"
#      input: "sequential_16_1/dense_65_1/Cast/ReadVariableOp:0"
#      output: "sequential_16_1/dense_65_1/MatMul:0"
#      name: "sequential_16_1/dense_65_1/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential_16_1/dense_65_1/MatMul:0"
#      input: "sequential_16_1/dense_65_1/BiasAdd/ReadVariableOp:0"
#      output: "sequential_16_1/dense_65_1/BiasAdd:0"
#      name: "sequential_16_1/dense_65_1/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential_16_1/dense_65_1/BiasAdd:0"
#      output: "sequential_16_1/dense_65_1/Tanh:0"
#      name: "sequential_16_1/dense_65_1/Tanh"
#      op_type: "Tanh"
#    }
#    node {
#      input: "sequential_16_1/dense_65_1/Tanh:0"
#      input: "sequential_16_1/dense_66_1/Cast/ReadVariableOp:0"
#      output: "sequential_16_1/dense_66_1/MatMul:0"
#      name: "sequential_16_1/dense_66_1/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential_16_1/dense_66_1/MatMul:0"
#      input: "sequential_16_1/dense_66_1/BiasAdd/ReadVariableOp:0"
#      output: "sequential_16_1/dense_66_1/BiasAdd:0"
#      name: "sequential_16_1/dense_66_1/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential_16_1/dense_66_1/BiasAdd:0"
#      output: "sequential_16_1/dense_66_1/Tanh:0"
#      name: "sequential_16_1/dense_66_1/Tanh"
#      op_type: "Tanh"
#    }
#    node {
#      input: "sequential_16_1/dense_66_1/Tanh:0"
#      input: "sequential_16_1/dense_67_1/Cast/ReadVariableOp:0"
#      output: "sequential_16_1/dense_67_1/MatMul:0"
#      name: "sequential_16_1/dense_67_1/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential_16_1/dense_67_1/MatMul:0"
#      input: "sequential_16_1/dense_67_1/Add/ReadVariableOp:0"
#      output: "sequential_16_1/dense_67_1/Add:0"
#      name: "sequential_16_1/dense_67_1/Add"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential_16_1/dense_67_1/Add:0"
#      output: "output"
#      name: "sequential_16_1/dense_67_1/Sigmoid"
#      op_type: "Sigmoid"
#    }
#    name: "tf2onnx"
#    initializer {
#      dims: 1
#      dims: 10
#      data_type: 1
#      name: "sequential_16_1/normalization_14_1/Sub/y:0"
#      raw_data: "-:V@\364 \003A\376Jx@\276F\304@Q3u@\016\224\304@.Qx@?!\310@\021,x@\241!\304@"
#    }
#    initializer {
#      dims: 64
#      dims: 1
#      data_type: 1
#      name: "sequential_16_1/dense_67_1/Cast/ReadVariableOp:0"
#      raw_data: "\320\250\\\277\215\232\033?&\021T\277\222\347)\277\20346\2772\273\234\276.qr?>\025\037?\377\0045?\252\\\333>%\346\277>#<V\277\021R\023?\032\0226?\352\371<\277n\207\024\277\276\217!\2771\334\336>\265\371J?Kl2?\234tP?m\010\177?-\331|?5OM\277\206\331/\277bf\363>\000\231\026?\211\3219\277\002\342\024\277~\276$\277,B<?\206U\375>\327\326\025\277%Q=\277\2668M\277\245<k\277\036\3653?^z@\277\200\327$?J\351q\277\024\362U?\006\205V?\336\223(\277\262\006\344\276C\302Z?N5\324>\204&\324>\340\264C\277\221I\243\276d\246I?Q\261D?$\'&?\334M\276>\213\206\236\276d\206\177?\030\344\347>U\307}?\204\206(\277R\373@\277\2024\037\277~\344\031?\335xr?\235\326F\277\017\2035?"
#    }
#    initializer {
#      dims: 1
#      data_type: 1
#      name: "sequential_16_1/dense_67_1/Add/ReadVariableOp:0"
#      raw_data: "#\342h\276"
#    }
#    initializer {
#      dims: 64
#      dims: 64
#      data_type: 1
#      name: "sequential_16_1/dense_66_1/Cast/ReadVariableOp:0"
#      raw_data: "\302\3441\276\020^\221=\210\321\234\276y\235\366>\243\327\r\277eqq\275\017\255F>,:\020\276`4 \276\363\307\244>\326\324\370>\331|\016?\256\201\334\274\000\244\006\276\031\347J\276\330Qa\274\211a\0009\362\370t\276\243\264\223\275\021\367\032>\242\322\317\276\2135\240\276\352L\264=^\347\267\276\td\317>\n\366\257>\315\330\277>\034\334\027>R\331\031\276X\244\206>\211y(\2766\366\252>\006\260\274\276\304\313\202>6!T>\225\366\031?\036\n\017>/\034C\275\2011|\276)2\207\276\366\202\016\277~\231\323\276\305\223\222;\215\026\225>m\362\254\276z\003\350\274\362{\017\276\275\345@\275qI\241=nu|\276m\312\037\276\271\3773=4\332W>\242^<>~\370\027>\222e\275>
#    }
#    initializer {
#      dims: 64
#      data_type: 1
#      name: "sequential_16_1/dense_64_1/BiasAdd/ReadVariableOp:0"
#      raw_data: "\344-\327\272K\007\236\275\316-1\276\230\273d=le\320=\030M\262=\361\221B\276K\210\342\275\317\270O\275T[\256=#X\254\275\223\035\304\275\311U\335\275b\006\213=\t\324(\276\3054\254<k\233\367=&\034\t=\203w\201=B\347W>\266A\244=\231_\\>\363\303\r\275\005\337\375<T\362\320=\244\322\210\275\323\342\273\275\t\020o<\277@\220\275\017\334.>\036\200=>\343\245O>\220\242`\274\207\261\322=3\262Y=\303\247\213\276\336W\022=\033\256\324\275\234\355J=\267\217\240<C]\004\276\224\n\033\276\013*\365\275\313\365\345=P\tB>\302\002E=WS?\275\361\225\302\275<1G\275r\2172>\320\037V\275\204\200h\275\177hY\276Lz\004\276K\276g\275\221N\r\276\006\364\035> \031\013\273#~F=\232\005\227=b&\006\274\354%#\274g5\331=\252k\255\275"
#    }
#    initializer {
#      dims: 1
#      dims: 10
#      data_type: 1
#      name: "ConstantFolding/sequential_16_1/normalization_14_1/truediv_recip:0"
#      raw_data: ">\030\r?\317\304\016>\314\007\023?#\305/>{\004\017?\240\244->$\331\017?0\316+>\"\021\020?\373\330+>"
#    }
#    doc_string: "converted from sequential_16"
#    input {
#      name: "digit"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__51"
#            }
#            dim {
#              dim_value: 10
#            }
#          }
#        }
#      }
#    }
#    output {
#      name: "output"
#      type {
#        tensor_type {
#          elem_type: 1
#          shape {
#            dim {
#              dim_param: "unk__52"
#            }
#            dim {
#              dim_value: 1
#            }
#          }
#        }
#      }
#    }
#  }
#  opset_import {
#    domain: ""
#    version: 13
#  }
#  opset_import {
#    domain: "ai.onnx.ml"
#    version: 2
#  },
#  None)

# %%
import onnx
import onnxruntime
import numpy as np
from itertools import product, chain
import time


def get_all_options(notes: list[int], max_fret: int = 24, strings: int = 6) -> list[tuple[int, int]]:
    ## note 0 is A440Hz at 5th fret, first string
    options = []
    string_offsets = [
        0,
        5,
        9,
        14,
        19,
        24
    ]
    for note in notes:
        opt = []
        for string in range(strings):
            fret = note + 5 + string_offsets[string]
            if fret < 0:
                continue
            if fret > max_fret:
                continue
            opt.append((string, fret))
        options.append(opt)
    return product(*options)

onnx_model = onnx.load('model_with_frets_and_strings.onnx')
onnx.checker.check_model(onnx_model)

def print_data_as_tab(data):
    for row in range(6):
        for column in range(len(data)):
            print("--", end="")
            if data[column][0] == row:
                num = str(data[column][1])
                if len(num) == 1:
                    print(num + "-", end="")
                else:
                    print(num, end="")
            else:
                print("--", end="")
        print()


ort_session = onnxruntime.InferenceSession('model_with_frets_and_strings.onnx')

# Check the model's input names
for input_meta in ort_session.get_inputs():
    print(input_meta.name)

begin = time.perf_counter_ns()
options = list(get_all_options([-5, -3, -2, -0, 2]))
input = [list(chain(*y)) for y in options]

# Update the input feed to match the expected input names
input_feed = {'digit': np.array(input, dtype=np.float32)}
output = ort_session.run(None, input_feed)

output = list(map(lambda x: float(list(x)[0]), output[0]))
options_outputs = zip(options, output)
options_outputs = sorted(options_outputs, key=lambda x: x[1], reverse=True)
print(f"Time taken: {(time.perf_counter_ns() - begin) / 1e6}ms to compute {len(options)} options")
for idx, (option, prob) in enumerate(options_outputs):
    print(f"top {idx+1} with probability of {prob}")
    print_data_as_tab(option)
    print()
# Out:
# digit
# Time taken: 13.532ms to compute 3000 options
# top 1 with probability of 0.9996461868286133
# --------------------
# --5---------------12
# ----------12--------
# ------16------------
# --------------24----
# --------------------
#
# top 2 with probability of 0.999273419380188
# --0-----------------
# ------------------12
# --------------------
# ------16--17--------
# --------------24----
# --------------------
#
# top 3 with probability of 0.9992437362670898
# --0---------------7-
# ----------8---------
# --------------------
# ------16------------
# --------------24----
# --------------------
#
# top 4 with probability of 0.9992058873176575
# --0---------------7-
# ------7---8---10----
# --------------------
# --------------------
# --------------------
# --------------------
#
# top 5 with probability of 0.9991062879562378
# --------------------
# --5---------------12
# ------11--12--14----
# --------------------
# --------------------
# --------------------
#
# top 6 with probability of 0.9990607500076294
# --------------------
# --------------------
# --9---------------16
# ------16--17--------
# --------------24----
# --------------------
#
# top 7 with probability of 0.9990445375442505
# --------------------
# ----------8-------12
# --9-----------------
# ------16------------
# --------------24----
# --------------------
#
# top 8 with probability of 0.9988933801651001
# ------------------7-
# --------------------
# --------------14----
# ------16------------
# ----------22--------
# --24----------------
#
# top 9 with probability of 0.9988158941268921
# ------------------7-
# --------------10----
# --------------------
# ------16------------
# ----------22--------
# --24----------------
#
# top 10 with probability of 0.9988006353378296
# --0---------------7-
# --------------------
# ----------12--------
# ------16------19----
# --------------------
# --------------------
#
# top 11 with probability of 0.998534619808197
# --0-----------------
# ------------------12
# --------------------
# ------16--17--19----
# --------------------
# --------------------
#
# top 12 with probability of 0.9984104633331299
# --------------------
# --5-----------------
# ------------------16
# --------------------
# ------21--22--24----
# --------------------
#
# top 13 with probability of 0.9983677864074707
# --0---------------7-
# ----------8---------
# ------11------14----
# --------------------
# --------------------
# --------------------
#
# top 14 with probability of 0.9983398914337158
# --0-----------------
# ------------------12
# --------------------
# ----------17--------
# ------21------24----
# --------------------
#
# top 15 with probability of 0.998291015625
# --------------------
# --5-------8-------12
# ------11------------
# --------------19----
# --------------------
# --------------------
#
# top 16 with probability of 0.9982335567474365
# ------------------7-
# --------------------
# --------------14----
# --------------------
# ------21--22--------
# --24----------------
#
# top 17 with probability of 0.9978603720664978
# ------------------7-
# --------------------
# --------------------
# --------------19----
# ------21--22--------
# --24----------------
#
# top 18 with probability of 0.9978300333023071
# ------------------7-
# --------------------
# --------------14----
# ------16------------
# --19------22--------
# --------------------
#
# top 19 with probability of 0.9978048801422119
# --------------------
# ------------------12
# --9-------12--------
# ------16------19----
# --------------------
# --------------------
#
# top 20 with probability of 0.9977973699569702
# ------------------7-
# --------------10----
# --------------------
# ------16------------
# --19------22--------
# --------------------
#
# top 21 with probability of 0.9977880120277405
# --------------------
# --------------------
# --9---------------16
# ----------17--------
# ------21------24----
# --------------------
#
# top 22 with probability of 0.99776291847229
# --------------------
# --------------------
# --9-------12------16
# ------16------------
# --------------24----
# --------------------
#
# top 23 with probability of 0.997748076915741
# --------------------
# --5---------------12
# ----------12--------
# ------16------19----
# --------------------
# --------------------
#
# top 24 with probability of 0.997683048248291
# --0-----------------
# ------------------12
# ------11------14----
# ----------17--------
# --------------------
# --------------------
#
# top 25 with probability of 0.9975888729095459
# --0-----------------
# ------------------12
# ----------12--------
# ------16------------
# --------------24----
# --------------------
#
# top 26 with probability of 0.9975811243057251
# --------------------
# --5-----------------
# ------------------16
# ------16--17--------
# --------------24----
# --------------------
#
# top 27 with probability of 0.9975153207778931
# --------------------
# --5---------------12
# --------------------
# ----------17--------
# ------21------24----
# --------------------
#
# top 28 with probability of 0.9975083470344543
# --------------------
# --------------------
# --9---------------16
# ------16--17--19----
# --------------------
# --------------------
#
# top 29 with probability of 0.9973884224891663
# --------------5-----
# ----------8---------
# --9---------------16
# --------------------
# ------21------------
# --------------------
#
# top 30 with probability of 0.9973651766777039
# --------------------
# --------------------
# --------------------
# --14--------------21
# ------21--22--24----
# --------------------
#
# top 31 with probability of 0.9973589181900024
# --------------5---7-
# --------------------
# --------------------
# ------16------------
# ----------22--------
# --24----------------
#
# top 32 with probability of 0.9972254633903503
# --------------------
# --5---------------12
# --------------------
# ------16--17--19----
# --------------------
# --------------------
#
# top 33 with probability of 0.9970043301582336
# --0-----------------
# ------------------12
# --------------------
# --------------------
# ------21--22--24----
# --------------------
#
# top 34 with probability of 0.9968764781951904
# --0---------------7-
# ----------8---------
# ------11------------
# --------------19----
# --------------------
# --------------------
#
# top 35 with probability of 0.9967923164367676
# --0-----------------
# ------------------12
# ------11--12--------
# --------------19----
# --------------------
# --------------------
#
# top 36 with probability of 0.9967869520187378
# --------------5-----
# --5-------8-------12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 37 with probability of 0.9967595338821411
# --0-----------------
# ----------8---10--12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 38 with probability of 0.9967437386512756
# --0-------3-------7-
# --------------10----
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 39 with probability of 0.9966585636138916
# --------------5-----
# ----------8-------12
# --9-----------------
# --------------------
# ------21------------
# --------------------
#
# top 40 with probability of 0.996573805809021
# --------------5-----
# --5-------8---------
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 41 with probability of 0.9965615272521973
# ------------------7-
# --------------10----
# ------11------------
# --------------------
# ----------22--------
# --24----------------
#
# top 42 with probability of 0.9964910745620728
# --------------------
# --5-------8-------12
# --------------------
# ------16------------
# --------------24----
# --------------------
#
# top 43 with probability of 0.9963138103485107
# --0---------------7-
# --------------------
# ------11--12--14----
# --------------------
# --------------------
# --------------------
#
# top 44 with probability of 0.9962843656539917
# --0-----------------
# ----------8---10----
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 45 with probability of 0.9960208535194397
# ------------------7-
# --------------------
# --------------------
# ------16------19----
# ----------22--------
# --24----------------
#
# top 46 with probability of 0.9959964752197266
# ----------3---------
# --5-----------10--12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 47 with probability of 0.9959754943847656
# --------------5---7-
# --------------------
# ------11------------
# --------------------
# ----------22--------
# --24----------------
#
# top 48 with probability of 0.9958398938179016
# ------------------7-
# --------------------
# --------------------
# ------16------19----
# --19------22--------
# --------------------
#
# top 49 with probability of 0.9958006143569946
# --------------5-----
# --5-----------------
# ----------12------16
# --------------------
# ------21------------
# --------------------
#
# top 50 with probability of 0.9957765340805054
# --0-----------5---7-
# ----------8---------
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 51 with probability of 0.9956731796264648
# --------------------
# ----------8-------12
# --9---11------14----
# --------------------
# --------------------
# --------------------
#
# top 52 with probability of 0.9956540465354919
# --------------5---7-
# --5-------8---------
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 53 with probability of 0.9956482648849487
# --0-------3-------7-
# --------------------
# --------------14----
# --------------------
# ------21------------
# --------------------
#
# top 54 with probability of 0.9955230951309204
# --0-----------5-----
# ------------------12
# ----------12--------
# --------------------
# ------21------------
# --------------------
#
# top 55 with probability of 0.9955153465270996
# ------------------7-
# --------------------
# --------------------
# --------------19----
# --19--21--22--------
# --------------------
#
# top 56 with probability of 0.9955098032951355
# --0-----------5-----
# --------------------
# ----------12------16
# --------------------
# ------21------------
# --------------------
#
# top 57 with probability of 0.9954843521118164
# --0---------------7-
# ----------8---10----
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 58 with probability of 0.9954822063446045
# --------------------
# --------------------
# ----------12------16
# --14--16------------
# --------------24----
# --------------------
#
# top 59 with probability of 0.995449423789978
# --0---2---3-------7-
# --------------10----
# --------------------
# --------------------
# --------------------
# --------------------
#
# top 60 with probability of 0.9952431917190552
# ------------------7-
# --------------10----
# ------11------------
# --------------------
# --19------22--------
# --------------------
#
# top 61 with probability of 0.9951542615890503
# --0---------------7-
# --------------------
# ----------12--------
# --------------------
# ------21------24----
# --------------------
#
# top 62 with probability of 0.9950902462005615
# ------------------7-
# --------------------
# ------11------------
# --------------------
# ----------22--24----
# --24----------------
#
# top 63 with probability of 0.9950891733169556
# --0-----------5---7-
# ----------8---------
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 64 with probability of 0.9950771927833557
# --0-----------5-----
# ----------8-------12
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 65 with probability of 0.995055079460144
# ----------3---5-----
# --------------------
# ------------------16
# --14----------------
# ------21------------
# --------------------
#
# top 66 with probability of 0.9949087500572205
# ----------3---5-----
# ------------------12
# --9-----------------
# --------------------
# ------21------------
# --------------------
#
# top 67 with probability of 0.994849681854248
# --0-----------5-----
# ----------8-------12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 68 with probability of 0.9947435259819031
# ----------3-------7-
# --5-----------10----
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 69 with probability of 0.9946284294128418
# ----------3---------
# --------------10----
# --9---------------16
# --------------------
# ------21------------
# --------------------
#
# top 70 with probability of 0.9945601224899292
# --------------5-----
# --5-------8-------12
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 71 with probability of 0.9945023059844971
# --------------5-----
# --5-------8---------
# ------------------16
# ------16------------
# --------------------
# --------------------
#
# top 72 with probability of 0.9944323301315308
# --------------------
# ------7---8---10--12
# --9-----------------
# --------------------
# --------------------
# --------------------
#
# top 73 with probability of 0.9943969249725342
# --0-------3---------
# --------------10--12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 74 with probability of 0.9942702651023865
# --------------5-----
# --5---------------12
# ----------12--------
# --------------------
# ------21------------
# --------------------
#
# top 75 with probability of 0.9941946268081665
# --------------5-----
# ----------8---------
# --9-----------------
# ------------------21
# ------21------------
# --------------------
#
# top 76 with probability of 0.9941189289093018
# --------------------
# --5-----------------
# ------------------16
# ----------17--------
# ------21------24----
# --------------------
#
# top 77 with probability of 0.994026780128479
# ------------------7-
# --------------------
# --------------------
# ------16------------
# ----------22--24----
# --24----------------
#
# top 78 with probability of 0.9939813613891602
# ----------3---5-----
# ------------------12
# --------------------
# --14----------------
# ------21------------
# --------------------
#
# top 79 with probability of 0.9939606189727783
# ----------3---5-----
# --------------------
# --9---------------16
# --------------------
# ------21------------
# --------------------
#
# top 80 with probability of 0.9939427375793457
# --------------------
# --5-----------------
# ------------------16
# ------16------19----
# ----------22--------
# --------------------
#
# top 81 with probability of 0.9938887357711792
# ----------3---------
# --5-----------10----
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 82 with probability of 0.9937283992767334
# ----------3---5---7-
# --5-----------------
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 83 with probability of 0.9936899542808533
# --0-------3---------
# ------------------12
# --------------14----
# --------------------
# ------21------------
# --------------------
#
# top 84 with probability of 0.9936777353286743
# --------------------
# --------------------
# --9---------------16
# --------------------
# ------21--22--24----
# --------------------
#
# top 85 with probability of 0.9936697483062744
# --0-----------5-----
# ----------8---------
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 86 with probability of 0.9936290979385376
# --0-----------------
# ----------8-------12
# ------11------------
# --------------------
# --------------24----
# --------------------
#
# top 87 with probability of 0.9935846924781799
# ----------3---------
# --------------10--12
# --9-----------------
# --------------------
# ------21------------
# --------------------
#
# top 88 with probability of 0.9935330152511597
# --------------5-----
# ----------8---------
# ------------------16
# --14----------------
# ------21------------
# --------------------
#
# top 89 with probability of 0.9934990406036377
# ------------------7-
# --------------10----
# --------------------
# --------------------
# ------21--22--------
# --24----------------
#
# top 90 with probability of 0.9934621453285217
# --------------------
# --5-----------------
# ----------12------16
# ------16------------
# --------------24----
# --------------------
#
# top 91 with probability of 0.9934513568878174
# --0-------3-------7-
# --------------10----
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 92 with probability of 0.9934351444244385
# --------------5-----
# --5-----------------
# ----------12--------
# ------------------21
# ------21------------
# --------------------
#
# top 93 with probability of 0.9933996796607971
# --------------------
# --------------10--12
# --------------------
# ------16------------
# ----------22--------
# --24----------------
#
# top 94 with probability of 0.993362545967102
# --0-----------5---7-
# --------------------
# ----------12--------
# --------------------
# ------21------------
# --------------------
#
# top 95 with probability of 0.9933261275291443
# ------------------7-
# --------------------
# ------11------------
# --------------19----
# ----------22--------
# --24----------------
#
# top 96 with probability of 0.9932732582092285
# ------------------7-
# ------7-------------
# --------------------
# --------------------
# ----------22--24----
# --24----------------
#
# top 97 with probability of 0.9931901097297668
# ------------------7-
# --5-------8---------
# --------------------
# ------16------19----
# --------------------
# --------------------
#
# top 98 with probability of 0.9930696487426758
# ------------------7-
# --------------------
# ------11------------
# --------------------
# --19------22--24----
# --------------------
#
# top 99 with probability of 0.9930219650268555
# ------------------7-
# --------------------
# --------------14----
# --------------------
# --19--21--22--------
# --------------------
#
# top 100 with probability of 0.9929807782173157
# ------------------7-
# --------------------
# ------11------14----
# --------------------
# ----------22--------
# --24----------------
#
# top 101 with probability of 0.992891252040863
# ------------------7-
# --------------------
# ------11------14----
# --------------------
# --19------22--------
# --------------------
#
# top 102 with probability of 0.9928393959999084
# --------------------
# --5-------8---10----
# --------------------
# ------------------21
# ------21------------
# --------------------
#
# top 103 with probability of 0.9927093386650085
# ----------3---5---7-
# --------------------
# --9-----------------
# --------------------
# ------21------------
# --------------------
#
# top 104 with probability of 0.9926573038101196
# --------------------
# --------------------
# --9---------------16
# --------------19----
# ------21--22--------
# --------------------
#
# top 105 with probability of 0.9926481246948242
# ----------3-------7-
# --5-----------------
# --------------14----
# --------------------
# ------21------------
# --------------------
#
# top 106 with probability of 0.9925549030303955
# ----------3---5-----
# --5---------------12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 107 with probability of 0.9924619197845459
# --------------------
# --5-------8---10----
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 108 with probability of 0.9924180507659912
# --------------------
# --5-----------------
# ------------------16
# ------16--17--19----
# --------------------
# --------------------
#
# top 109 with probability of 0.9923290014266968
# --0-----------------
# ------------------12
# ----------12--------
# ------16------19----
# --------------------
# --------------------
#
# top 110 with probability of 0.99232017993927
# --0-----------------
# ----------8---10----
# --------------------
# ------------------21
# ------21------------
# --------------------
#
# top 111 with probability of 0.9922764301300049
# --------------5-----
# --------------------
# --9-------12--------
# ------------------21
# ------21------------
# --------------------
#
# top 112 with probability of 0.9922680854797363
# --0-------3---5---7-
# --------------------
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 113 with probability of 0.9922664761543274
# --------------5-----
# --------------------
# --9-------12------16
# --------------------
# ------21------------
# --------------------
#
# top 114 with probability of 0.9921404123306274
# --0-----------------
# ------------------12
# --------------------
# --------------19----
# ------21--22--------
# --------------------
#
# top 115 with probability of 0.9921365976333618
# ----------3---5---7-
# --5-----------------
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 116 with probability of 0.9919548630714417
# --0-----------5-----
# ------------------12
# ----------12--------
# ------16------------
# --------------------
# --------------------
#
# top 117 with probability of 0.99193274974823
# --------------------
# --5---7-------10--12
# ----------12--------
# --------------------
# --------------------
# --------------------
#
# top 118 with probability of 0.9918708801269531
# --0-------3---5---7-
# --------------------
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 119 with probability of 0.9917944669723511
# --0-----------5-----
# --------------------
# ----------12------16
# ------16------------
# --------------------
# --------------------
#
# top 120 with probability of 0.99162757396698
# --------------5---7-
# --------------------
# ------11------------
# --------------------
# --19------22--------
# --------------------
#
# top 121 with probability of 0.9916155338287354
# --0-------3---------
# --------------10--12
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 122 with probability of 0.9915257692337036
# --0-----------5-----
# ----------8---------
# ------------------16
# ------16------------
# --------------------
# --------------------
#
# top 123 with probability of 0.9914454221725464
# ----------3---5-----
# --5---------------12
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 124 with probability of 0.9914418458938599
# --------------------
# --------------------
# ------------------16
# --14------17--------
# ------21------24----
# --------------------
#
# top 125 with probability of 0.9912580251693726
# ----------3---5-----
# ------------------12
# --9-----------------
# ------16------------
# --------------------
# --------------------
#
# top 126 with probability of 0.9911606311798096
# ------------------7-
# --------------------
# --------------------
# --------------------
# ------21--22--24----
# --24----------------
#
# top 127 with probability of 0.9909501075744629
# --0-------3-------7-
# --------------------
# --------------14----
# ------16------------
# --------------------
# --------------------
#
# top 128 with probability of 0.990936815738678
# --0-----------------
# --------------10--12
# ------11------------
# ----------17--------
# --------------------
# --------------------
#
# top 129 with probability of 0.9909322261810303
# --------------5-----
# ----------8---------
# --------------------
# --14--------------21
# ------21------------
# --------------------
#
# top 130 with probability of 0.9907848238945007
# --0-------3---------
# --------------------
# --------------14--16
# --------------------
# ------21------------
# --------------------
#
# top 131 with probability of 0.9907628297805786
# --------------5-----
# --5-------8---------
# --------------------
# ------------------21
# ------21------------
# --------------------
#
# top 132 with probability of 0.9906961917877197
# --0---------------7-
# --------------------
# --------------------
# ----------17--19----
# ------21------------
# --------------------
#
# top 133 with probability of 0.9906682968139648
# --0-------3---------
# --------------10----
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 134 with probability of 0.990666389465332
# ------------------7-
# --------------------
# ------11------------
# --------------19----
# --19------22--------
# --------------------
#
# top 135 with probability of 0.9906662702560425
# ----------3-------7-
# --------------------
# --9-----------14----
# --------------------
# ------21------------
# --------------------
#
# top 136 with probability of 0.9906604290008545
# --0-----------5-----
# --------------------
# ------------------16
# ----------17--------
# ------21------------
# --------------------
#
# top 137 with probability of 0.9905433654785156
# --0-------3---5---7-
# --------------------
# ------11------------
# --------------------
# --------------------
# --------------------
#
# top 138 with probability of 0.9903380870819092
# --0-------3-------7-
# --------------------
# --------------------
# --------------19----
# ------21------------
# --------------------
#
# top 139 with probability of 0.990167498588562
# --------------5-----
# ----------8---------
# --9---------------16
# ------16------------
# --------------------
# --------------------
#
# top 140 with probability of 0.9899107217788696
# --0---2-------5---7-
# ----------8---------
# --------------------
# --------------------
# --------------------
# --------------------
#
# top 141 with probability of 0.9897949695587158
# ----------3-------7-
# --5-----------------
# --------------14----
# ------16------------
# --------------------
# --------------------
#
# top 142 with probability of 0.9897143840789795
# --0---------------7-
# ----------8---------
# --------------------
# ------16------19----
# --------------------
# --------------------
#
# top 143 with probability of 0.989578902721405
# ------2---3---5---7-
# --5-----------------
# --------------------
# --------------------
# --------------------
# --------------------
#
# top 144 with probability of 0.9894366264343262
# --0-----------5-----
# --------------------
# ----------12--------
# ------------------21
# ------21------------
# --------------------
#
# top 145 with probability of 0.9893800020217896
# --0-----------------
# --------------------
# ------------------16
# --------------------
# ------21--22--24----
# --------------------
#
# top 146 with probability of 0.9893471598625183
# --0-----------------
# --------------10----
# ----------12--------
# ------------------21
# ------21------------
# --------------------
#
# top 147 with probability of 0.9892436265945435
# ----------3---5-----
# --5-----------------
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 148 with probability of 0.9891877174377441
# --------------5-----
# ------------------12
# ------11------------
# --------------------
# ----------22--------
# --24----------------
#
# top 149 with probability of 0.9889897108078003
# ------------------7-
# --------------------
# ------11------------
# --14----------------
# ----------22--24----
# --------------------
#
# top 150 with probability of 0.9886936545372009
# ------------------7-
# --------------------
# --------------------
# --------------------
# --19--21--22--24----
# --------------------
#
# top 151 with probability of 0.9886756539344788
# --------------------
# --5---------------12
# ----------12--------
# --------------------
# ------21------24----
# --------------------
#
# top 152 with probability of 0.9883830547332764
# --0-----------------
# ------------------12
# --------------14----
# ------16------------
# ----------22--------
# --------------------
#
# top 153 with probability of 0.9883260130882263
# --0-----------------
# ----------8---10--12
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 154 with probability of 0.9881218671798706
# --------------------
# --5-----------10--12
# ------11------------
# ----------17--------
# --------------------
# --------------------
#
# top 155 with probability of 0.9881212711334229
# --------------------
# --5-------8-------12
# ------11------14----
# --------------------
# --------------------
# --------------------
#
# top 156 with probability of 0.988093912601471
# --0---------------7-
# ----------8---------
# --------------14----
# --------------------
# ------21------------
# --------------------
#
# top 157 with probability of 0.9880872964859009
# --------------5---7-
# ------7-------------
# --------------------
# --------------------
# ----------22--------
# --24----------------
#
# top 158 with probability of 0.9880409836769104
# --0-----------------
# ------------------12
# --------------14----
# ------16--17--------
# --------------------
# --------------------
#
# top 159 with probability of 0.9879287481307983
# --------------------
# --5-------8---10--12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 160 with probability of 0.9878866076469421
# --0-----------------
# ----------8---10----
# ------------------16
# ------16------------
# --------------------
# --------------------
#
# top 161 with probability of 0.9877310991287231
# ------------------7-
# --------------------
# --------------------
# ------16------------
# --19------22--24----
# --------------------
#
# top 162 with probability of 0.9875667691230774
# ------------------7-
# --------------------
# ------11------------
# ----------17--------
# --------------24----
# --24----------------
#
# top 163 with probability of 0.9875662326812744
# --0-------3---5-----
# ------------------12
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 164 with probability of 0.9873688817024231
# --0-----------5-----
# ----------8-------12
# ------11------------
# --------------------
# --------------------
# --------------------
#
# top 165 with probability of 0.9872810244560242
# --------------5---7-
# --------------------
# --------------------
# ------16------------
# --19------22--------
# --------------------
#
# top 166 with probability of 0.9871934652328491
# ----------3-------7-
# --------------10----
# --9-----------------
# --------------------
# ------21------------
# --------------------
#
# top 167 with probability of 0.9871625900268555
# ----------3-------7-
# --5-----------------
# --------------------
# ------16------------
# --------------24----
# --------------------
#
# top 168 with probability of 0.986868679523468
# ------------------7-
# --------------------
# ------11------------
# ----------17--------
# --19----------24----
# --------------------
#
# top 169 with probability of 0.9868497252464294
# --------------------
# ------------------12
# --9-------12--------
# --------------------
# ------21------24----
# --------------------
#
# top 170 with probability of 0.9865797758102417
# ----------3-------7-
# --5-----------------
# --------------------
# --------------19----
# ------21------------
# --------------------
#
# top 171 with probability of 0.9864436388015747
# --------------------
# --------------------
# --9-----------------
# ------------------21
# ------21--22--24----
# --------------------
#
# top 172 with probability of 0.9863865971565247
# ------------------7-
# --------------------
# --------------14----
# ------16--17--------
# --------------------
# --24----------------
#
# top 173 with probability of 0.9863283634185791
# --------------5---7-
# ------7-------------
# --------------------
# --------------------
# --19------22--------
# --------------------
#
# top 174 with probability of 0.986051082611084
# --0-------3---5-----
# ------------------12
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 175 with probability of 0.9860118627548218
# --0---------------7-
# --------------10----
# ------11--12--------
# --------------------
# --------------------
# --------------------
#
# top 176 with probability of 0.9858358502388
# ------------------7-
# ------7-------10----
# --------------------
# --------------------
# --19------22--------
# --------------------
#
# top 177 with probability of 0.9857459664344788
# ----------3---------
# --5---------------12
# --------------14----
# --------------------
# ------21------------
# --------------------
#
# top 178 with probability of 0.9856719970703125
# --------------------
# --------------------
# ------------------16
# --14--16--17--19----
# --------------------
# --------------------
#
# top 179 with probability of 0.9855555295944214
# --0---------------7-
# ------7---8---------
# --------------14----
# --------------------
# --------------------
# --------------------
#
# top 180 with probability of 0.9854859113693237
# ----------3-------7-
# --------------------
# --9-----------14----
# ------16------------
# --------------------
# --------------------
#
# top 181 with probability of 0.985470175743103
# --0-----------5-----
# ------------------12
# --------------------
# ----------17--------
# ------21------------
# --------------------
#
# top 182 with probability of 0.9853000640869141
# ------------------7-
# --------------------
# --------------------
# --14--16------19----
# ----------22--------
# --------------------
#
# top 183 with probability of 0.9852979183197021
# --0-------3-------7-
# ------7-------------
# --------------14----
# --------------------
# --------------------
# --------------------
#
# top 184 with probability of 0.9852606058120728
# --------------------
# --5---------------12
# --------------14----
# ------16--17--------
# --------------------
# --------------------
#
# top 185 with probability of 0.9852030873298645
# ----------3---------
# --5-----------10--12
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 186 with probability of 0.9848175048828125
# ------------------7-
# ------7-------------
# --------------------
# --------------19----
# ----------22--------
# --24----------------
#
# top 187 with probability of 0.9847404956817627
# --------------------
# --5-----------10--12
# ------11--12--------
# --------------------
# --------------------
# --------------------
#
# top 188 with probability of 0.9846749305725098
# --0-----------------
# ------------------12
# ------11--12--------
# --------------------
# --------------24----
# --------------------
#
# top 189 with probability of 0.9844689965248108
# --------------5---7-
# ----------8---------
# --9-----------------
# --------------------
# ------21------------
# --------------------
#
# top 190 with probability of 0.9844132661819458
# --0-----------------
# --------------10----
# ----------12------16
# --------------------
# ------21------------
# --------------------
#
# top 191 with probability of 0.9843181371688843
# ------------------7-
# --------------------
# --------------14----
# --14--16------------
# ----------22--------
# --------------------
#
# top 192 with probability of 0.9842968583106995
# --------------------
# --------------------
# ----------12------16
# --14--16------19----
# --------------------
# --------------------
#
# top 193 with probability of 0.9842923283576965
# ----------3---------
# --5-----------------
# --------------14--16
# --------------------
# ------21------------
# --------------------
#
# top 194 with probability of 0.9842826724052429
# --0---------------7-
# ----------8---10----
# ------11------------
# --------------------
# --------------------
# --------------------
#
# top 195 with probability of 0.9842135906219482
# ----------3---5-----
# --------------------
# --9---------------16
# ------16------------
# --------------------
# --------------------
#
# top 196 with probability of 0.9836215376853943
# --0-----------------
# ----------8---------
# --------------14----
# ------------------21
# ------21------------
# --------------------
#
# top 197 with probability of 0.9832595586776733
# --0-----------------
# ----------8-------12
# --------------14----
# --------------------
# ------21------------
# --------------------
#
# top 198 with probability of 0.9831790924072266
# ----------3---------
# --------------10----
# --9-----------------
# ------------------21
# ------21------------
# --------------------
#
# top 199 with probability of 0.9831558465957642
# ------------------7-
# --------------10----
# --------------------
# ------16--17--------
# --------------------
# --24----------------
#
# top 200 with probability of 0.9830435514450073
# --------------------
# --5---7---8-------12
# --------------14----
# --------------------
# --------------------
# --------------------
#
# top 201 with probability of 0.9830418825149536
# --0-------3---5-----
# --------------------
# ------------------16
# --------------------
# ------21------------
# --------------------
#
# top 202 with probability of 0.9829509258270264
# --------------------
# ----------8---10----
# --9-----------------
# ------------------21
# ------21------------
# --------------------
#
# top 203 with probability of 0.9829332828521729
# ------------------7-
# --------------------
# ------11------------
# --14----------19----
# ----------22--------
# --------------------
#
# top 204 with probability of 0.9828007221221924
# --------------------
# ----------8---------
# --9---------------16
# ------16------------
# --------------24----
# --------------------
#
# top 205 with probability of 0.982724666595459
# --0-----------------
# ----------8---------
# --------------14--16
# --------------------
# ------21------------
# --------------------
#
# top 206 with probability of 0.9826847314834595
# --0-----------------
# --------------------
# ------------------16
# ------16--17--------
# --------------24----
# --------------------
#
# top 207 with probability of 0.9826626777648926
# --------------------
# --------------------
# --9-------12------16
# ------16------19----
# --------------------
# --------------------
#
# top 208 with probability of 0.9826278686523438
# --0-----------5-----
# ----------8---------
# --------------------
# ------------------21
# ------21------------
# --------------------
#
# top 209 with probability of 0.9826064109802246
# --0-----------------
# ------------------12
# ------11--12--14----
# --------------------
# --------------------
# --------------------
#
# top 210 with probability of 0.9826015830039978
# ----------3-------7-
# --5-----------10----
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 211 with probability of 0.982297420501709
# --------------------
# --5-----------------
# ------------------16
# --------------19----
# ------21--22--------
# --------------------
#
# top 212 with probability of 0.9822232723236084
# --0---------------7-
# --------------------
# ----------12--14----
# ------16------------
# --------------------
# --------------------
#
# top 213 with probability of 0.9821820259094238
# --0-----------5---7-
# ----------8---------
# ------11------------
# --------------------
# --------------------
# --------------------
#
# top 214 with probability of 0.9821419715881348
# --------------5-----
# --5-----------------
# ----------12------16
# ------16------------
# --------------------
# --------------------
#
# top 215 with probability of 0.982140064239502
# --0-------3---------
# --------------------
# --------------14----
# ------------------21
# ------21------------
# --------------------
#
# top 216 with probability of 0.9820215702056885
# --------------5-----
# ------------------12
# --9-------12--------
# --------------------
# ------21------------
# --------------------
#
# top 217 with probability of 0.9820057153701782
# --------------------
# --------------------
# --9-----------14--16
# ------16------------
# ----------22--------
# --------------------
#
# top 218 with probability of 0.9818552732467651
# --------------------
# ----------8-------12
# --9-----------------
# ------16------19----
# --------------------
# --------------------
#
# top 219 with probability of 0.981853723526001
# --0-------3-------7-
# --------------10----
# ------11------------
# --------------------
# --------------------
# --------------------
#
# top 220 with probability of 0.9817965030670166
# --0-----------------
# ----------8-------12
# --------------------
# ------16------------
# --------------24----
# --------------------
#
# top 221 with probability of 0.9815529584884644
# ------------------7-
# --------------------
# --------------------
# ------16--17--------
# --------------24----
# --24----------------
#
# top 222 with probability of 0.9815319776535034
# ----------3---5-----
# --------------------
# ------------------16
# --------------------
# --19--21------------
# --------------------
#
# top 223 with probability of 0.9813696146011353
# ------2-----------7-
# --------------------
# --------------------
# --------------------
# ----------22--24----
# --24----------------
#
# top 224 with probability of 0.9812893867492676
# --0-----------------
# ----------8-------12
# ------11------------
# --------------19----
# --------------------
# --------------------
#
# top 225 with probability of 0.9812481999397278
# --------------------
# --5-----------------
# ------------------16
# ------16------------
# ----------22--24----
# --------------------
#
# top 226 with probability of 0.9812472462654114
# --------------5-----
# ----------8-------12
# --------------------
# --14----------------
# ------21------------
# --------------------
#
# top 227 with probability of 0.9812201261520386
# --0-------3---------
# --------------10----
# ------------------16
# ------16------------
# --------------------
# --------------------
#
# top 228 with probability of 0.9812081456184387
# --------------------
# --5---------------12
# --------------------
# --------------19----
# ------21--22--------
# --------------------
#
# top 229 with probability of 0.9811909198760986
# ------------------7-
# --------------------
# --------------------
# --14--16------------
# ----------22--24----
# --------------------
#
# top 230 with probability of 0.9811674356460571
# --0-----------5---7-
# ------7---8---------
# --------------------
# --------------------
# --------------------
# --------------------
#
# top 231 with probability of 0.981110692024231
# --------------------
# --5-----------------
# --------------14--16
# ------16------------
# ----------22--------
# --------------------
#
# top 232 with probability of 0.981107234954834
# --0---------------7-
# --------------------
# --------------14----
# ------16--17--------
# --------------------
# --------------------
#
# top 233 with probability of 0.9809921979904175
# ----------3-------7-
# --------------------
# --9-----------------
# --------------19----
# ------21------------
# --------------------
#
# top 234 with probability of 0.9809389114379883
# --------------------
# --------------------
# --9---11--12------16
# --------------19----
# --------------------
# --------------------
#
# top 235 with probability of 0.9805706739425659
# ----------3---------
# --5-----------10----
# --------------------
# ------------------21
# ------21------------
# --------------------
#
# top 236 with probability of 0.9804969429969788
# ------------------7-
# ------7-------10----
# --------------------
# --14----------------
# ----------22--------
# --------------------
#
# top 237 with probability of 0.9803493022918701
# --0-------3---------
# ------------------12
# --------------14----
# ------16------------
# --------------------
# --------------------
#
# top 238 with probability of 0.980318546295166
# --------------------
# --5---------------12
# --------------------
# ----------17--19----
# ------21------------
# --------------------
#
# top 239 with probability of 0.9802905321121216
# ------------------7-
# ------7-------------
# --------------------
# --------------------
# --19------22--24----
# --------------------
#
# top 240 with probability of 0.9801082611083984
# --0-----------5-----
# --------------------
# --------------------
# ----------17------21
# ------21------------
# --------------------
#
# top 241 with probability of 0.980063796043396
# --------------------
# --------------------
# --------------------
# --------------19--21
# --19--21--22--------
# --------------------
#
# top 242 with probability of 0.980008602142334
# ------------------7-
# ------7-------------
# --------------------
# --14----------------
# ----------22--24----
# --------------------
#
# top 243 with probability of 0.9799203872680664
# --------------------
# --------------10--12
# --9---11--12--------
# --------------------
# --------------------
# --------------------
#
# top 244 with probability of 0.9796570539474487
# ------------------7-
# --------------10----
# ------11------------
# --14----------------
# ----------22--------
# --------------------
#
# top 245 with probability of 0.9795478582382202
# ------------------7-
# --5-------8---10----
# --------------------
# --------------------
# ------21------------
# --------------------
#
# top 246 with probability of 0.9794726371765137
# --0-------3---------
# --------------10----
# --------------------
# ------------------21
# ------21------------
# --------------------
#
# top 247 with probability of 0.9794557690620422
# --0---------------7-
# ----------8---------
# --------------14----
# ------16------------
# --------------------
# --------------------
#
# top 248 with probability of 0.9794424772262573
# --------------------
# --5-----------------
# ------11--12------16
# --------------------
# --------------24----
# --------------------
#
# top 249 with probability of 0.9792945981025696
# --------------------
# --------------------
# --------------------
# ----------17------21
# --19--21------24----
# --------------------
#
# top 250 with probability of 0.9787043333053589
# --------------5---7-
# --------------------
# ------11------------
# --14----------------
# ----------22--------
# --------------------
#
# top 251 with probability of 0.9785939455032349
# --0---------------7-
# ----------8---10----
# --------------------
# ------16------------
# --------------------
# --------------------
#
# top 252 with probability of 0.9783363938331604
# --0-------3-------7-
# --------------------
# ------11------------
# --------------------
# --------------24----
# --------------------
#
# top 253 with probability of 0.9782983064651489
# ------------------7-
# ------7-------------
# --------------------
# ----------17--------
# --------------24----
# --24----------------
#
# top 254 with probability of 0.9782679677009583
# ------------------7-
# --------------------
# ------11------14----
# --14----------------
# ----------22--------
# --------------------
#
# top 255 with probability of 0.9782273173332214
# ----------3---5-----
# --5-----------------
# ------------------16
# ------16------------
# --------------------
# --------------------
#
# top 256 with probability of 0.9782005548477173
# ------------------7-
# --5-------8---10----
# ------11------------
# --------------------
# --------------------
# --------------------
#
# top 257 with probability of 0.9776402115821838
# --0-------3-------7-
# ------7-------10----
# --------------------
# --------------------
# --------------------
# --------------------
#
# top 258 with probability of 0.9775291085243225
# --------------------
# --------------------
# --------------14--16
# --14--16--17--------
# --------------------
# --------------------
#
# top 259 with probability of 0.977462112903595
# ----------3---5---7-
# --------------------
# --9-----------------
# ------16------------
# --------------------
# --------------------
#
# top 260 with probability of 0.9774364233016968
# ----------3---------
# --5-----------10----
# ------------------16
# ------16------------
# --------------------
# --------------------
#
# top 261 with probability of 0.9773021936416626
# ----------3---------
# --5-----------------
# --------------14----
# ------------------21
# ------21------------
# --------------------
#
# top 262 with probability of 0.977063775062561
# --------------5-----
# ----------8-------12
# --9-----------------
# ------16------------
# --------------------
# --------------------
#
# top 263 with probability of 0.977005124092102
# --------------5-----
# ------------------12
# --------------------
# ------16------------
# ----------22--------
# --24----------------
#
# top 264 with probability of 0.9767971038818359
# ------------------7-
# --------------------
# --------------------
# --14----------------
# ------21--22--24----
# --------------------
#
# top 265 with probability of 0.9767000675201416
# ------------------7-
# --------------------
# --9---11------------
# --------------------
# ----------22--24----
# --------------------
#
# top 266 with probability of 0.9766555428504944
# --0-------3---5---7-
# ------7-------------
# --------------------
# --------------------
# --------------------
# --------------------
#
# top 267 with probability of 0.9765734076499939
# ------------------7-
# ------7-------------
# --------------------
# --14----------19----
# ----------22--------
# --------------------
#
# top 268 with probability of 0.9764161109924316
# --0-------3-------7-
# --------------------
# ------11------14----
# --------------------
# --------------------
# --------------------
#
# top 269 with probability of 0.9757480621337891
# --0-----------------
# --------------10--12
# ----------12--------
# --------------------
# ------21------------
# --------------------
#
# top 270 with probability of 0.9756627678871155
# ------------------7-
# ------7-------------
# --------------------
# --------------19----
# --19------22--------
# --------------------
#
# top 271 with probability of 0.9755685329437256
# --------------------
# ------------------12
# --------------14----
# ------16------------
# ----------22--------
# --24----------------
#
# top 272 with probability of 0.9754045009613037
# --------------------
# --------------------
# --------------------
# ------------------21
# --19--21--22--24----
# --------------------
#
# top 273 with probability of 0.9752875566482544
# ------------------7-
# --------------10----
# --------------------
# --14--16------------
# ----------22--------
# --------------------
#
# top 274 with probability of 0.9749023914337158
# ----------3-------7-
# --5-----------10----
# ------11------------
# --------------------
# --------------------
# --------------------
#
# top 275 with probability of 0.974755585193634
# --------------------
# --5-------8-------12
# --------------------
# ------16------19----
# --------------------
# --------------------
#
# top 276 with probability of 0.9747110605239868
# ------------------7-
# --------------------
# ------11------------
# --14------17--------
# --------------24----
# --------------------
#
# top 277 with probability of 0.9745636582374573
# --0-----------------
# ...
# ------2---3---------
# --------------10----
# ------------------16
# --------------------
# --------------------
# --24----------------
#
# top 2912 with probability of 3.382563591003418e-05
# ------2-------------
# --------------------
# --------------------
# --14------17------21
# --------------24----
# --------------------
#
# top 2913 with probability of 3.3229589462280273e-05
# ------2---3---------
# --5-----------10----
# --------------------
# ------------------21
# --------------------
# --------------------
#
# top 2914 with probability of 3.281235694885254e-05
# --------------------
# --5---7-------------
# --------------------
# --------------19--21
# ----------22--------
# --------------------
#
# top 2915 with probability of 3.17990779876709e-05
# ------2-------5-----
# --------------------
# --9---------------16
# --------------------
# ----------22--------
# --------------------
#
# top 2916 with probability of 3.126263618469238e-05
# ------2-------------
# --------------------
# --9-----------------
# --------------19--21
# ----------22--------
# --------------------
#
# top 2917 with probability of 3.102421760559082e-05
# ------2-------------
# --5-----------10----
# ------------------16
# --------------------
# ----------22--------
# --------------------
#
# top 2918 with probability of 2.9981136322021484e-05
# ------2-------5-----
# --5-----------------
# ----------12--------
# ------------------21
# --------------------
# --------------------
#
# top 2919 with probability of 2.9534101486206055e-05
# ----------3---5-----
# --------------------
# ------11------------
# ------------------21
# --------------------
# --24----------------
#
# top 2920 with probability of 2.9295682907104492e-05
# ------2-------------
# --5-----------10----
# --------------------
# ----------17------21
# --------------------
# --------------------
#
# top 2921 with probability of 2.917647361755371e-05
# ------2-------------
# --------------10----
# ----------12--------
# ------------------21
# --------------------
# --24----------------
#
# top 2922 with probability of 2.726912498474121e-05
# ----------3---5-----
# ------7-------------
# ------------------16
# --------------------
# --19----------------
# --------------------
#
# top 2923 with probability of 2.7000904083251953e-05
# ------2-------------
# --------------------
# --------------------
# --14--------------21
# ----------22--24----
# --------------------
#
# top 2924 with probability of 2.6732683181762695e-05
# ------2-------5-----
# --------------------
# --------------------
# ------------------21
# --19------22--------
# --------------------
#
# top 2925 with probability of 2.5928020477294922e-05
# ------2-------------
# --------------------
# --------------14----
# ----------17------21
# --------------------
# --24----------------
#
# top 2926 with probability of 2.5928020477294922e-05
# ----------3---------
# --------------------
# --------------14----
# ------16----------21
# --------------------
# --24----------------
#
# top 2927 with probability of 2.5719404220581055e-05
# --------------5-----
# ----------8---------
# ------11------------
# ------------------21
# --------------------
# --24----------------
#
# top 2928 with probability of 2.536177635192871e-05
# ------2-------------
# ----------8---10----
# ------------------16
# --------------------
# --------------------
# --24----------------
#
# top 2929 with probability of 2.4944543838500977e-05
# ------2-------5-----
# --5-----------------
# ----------12------16
# --------------------
# --------------------
# --------------------
#
# top 2930 with probability of 2.485513687133789e-05
# ------2-------------
# ----------8---------
# --------------------
# --------------19--21
# --------------------
# --24----------------
#
# top 2931 with probability of 2.4765729904174805e-05
# ------2-------------
# --------------------
# --------------------
# --------------19--21
# --19------22--------
# --------------------
#
# top 2932 with probability of 2.4646520614624023e-05
# ------2-------5-----
# --------------------
# ----------12--------
# --14--------------21
# --------------------
# --------------------
#
# top 2933 with probability of 2.4527311325073242e-05
# ------2---3---------
# --------------------
# --------------14----
# --14--------------21
# --------------------
# --------------------
#
# top 2934 with probability of 2.4437904357910156e-05
# ------2-------------
# --------------10----
# --------------------
# ----------17------21
# --19----------------
# --------------------
#
# top 2935 with probability of 2.4259090423583984e-05
# ------2-------------
# --------------------
# ----------12--14----
# ------------------21
# --19----------------
# --------------------
#
# top 2936 with probability of 2.390146255493164e-05
# --------------5-----
# ------7-------------
# --------------------
# ----------17------21
# --19----------------
# --------------------
#
# top 2937 with probability of 2.3126602172851562e-05
# ------2---3---------
# --5-----------------
# --------------------
# --------------19--21
# --------------------
# --------------------
#
# top 2938 with probability of 2.2679567337036133e-05
# ------2-------5-----
# --5---------------12
# ----------12--------
# --------------------
# --------------------
# --------------------
#
# top 2939 with probability of 2.2679567337036133e-05
# --------------------
# ------7-------10----
# --------------------
# --14------17------21
# --------------------
# --------------------
#
# top 2940 with probability of 2.238154411315918e-05
# ------2-------------
# --------------------
# --------------------
# --14------17--19--21
# --------------------
# --------------------
#
# top 2941 with probability of 2.2292137145996094e-05
# ----------3---------
# ------------------12
# --------------------
# ------16------19----
# --------------------
# --24----------------
#
# top 2942 with probability of 2.1457672119140625e-05
# ------2-------------
# --------------------
# --------------------
# --14----------19--21
# ----------22--------
# --------------------
#
# top 2943 with probability of 2.092123031616211e-05
# --------------5-----
# ------7-------------
# --9-----------------
# ------------------21
# ----------22--------
# --------------------
#
# top 2944 with probability of 2.0384788513183594e-05
# --------------------
# ------7-------------
# --------------14----
# --14------17------21
# --------------------
# --------------------
#
# top 2945 with probability of 1.9162893295288086e-05
# --0---2-------5-----
# ------------------12
# --------------------
# --------------------
# ----------22--------
# --------------------
#
# top 2946 with probability of 1.895427703857422e-05
# ------2-------------
# ----------8---10----
# --------------------
# ------------------21
# --------------------
# --24----------------
#
# top 2947 with probability of 1.8477439880371094e-05
# ------2-------------
# --------------------
# --------------14----
# ----------17------21
# --19----------------
# --------------------
#
# top 2948 with probability of 1.7940998077392578e-05
# --------------------
# ----------8---------
# --------------14----
# ------16----------21
# --------------------
# --24----------------
#
# top 2949 with probability of 1.7821788787841797e-05
# --------------5-----
# ----------8-------12
# ------11------------
# --------------------
# --------------------
# --24----------------
#
# top 2950 with probability of 1.7523765563964844e-05
# ------2---3---------
# --------------------
# --9-----------------
# --------------19--21
# --------------------
# --------------------
#
# top 2951 with probability of 1.7523765563964844e-05
# --------------------
# ----------8---------
# ------------------16
# ------16------19----
# --------------------
# --24----------------
#
# top 2952 with probability of 1.5914440155029297e-05
# ------2-------5-----
# --------------------
# --9-------12--------
# ------------------21
# --------------------
# --------------------
#
# top 2953 with probability of 1.5497207641601562e-05
# ------2-------------
# --------------------
# --------------14----
# --14--------------21
# ----------22--------
# --------------------
#
# top 2954 with probability of 1.5407800674438477e-05
# --------------------
# ------7-------------
# --------------14----
# --14--------------21
# ----------22--------
# --------------------
#
# top 2955 with probability of 1.4781951904296875e-05
# --------------5-----
# ------7-------------
# --------------------
# ----------17------21
# --------------------
# --24----------------
#
# top 2956 with probability of 1.4185905456542969e-05
# ------2-------------
# --------------------
# ----------12--------
# --------------19--21
# --19----------------
# --------------------
#
# top 2957 with probability of 1.3768672943115234e-05
# --------------------
# ----------8-------12
# --------------14----
# ------16------------
# --------------------
# --24----------------
#
# top 2958 with probability of 1.3619661331176758e-05
# ------2-------------
# ----------8---------
# --------------14--16
# --------------------
# --19----------------
# --------------------
#
# top 2959 with probability of 1.341104507446289e-05
# ------2-------------
# --------------10----
# ----------12--------
# ------------------21
# --19----------------
# --------------------
#
# top 2960 with probability of 1.3053417205810547e-05
# ------2-------------
# --------------------
# ----------12--------
# --------------19--21
# --------------------
# --24----------------
#
# top 2961 with probability of 1.3053417205810547e-05
# --------------------
# ----------8---10----
# ------11----------16
# --------------------
# --------------------
# --24----------------
#
# top 2962 with probability of 1.150369644165039e-05
# ----------3---------
# --------------10--12
# ------11------------
# --------------------
# --------------------
# --24----------------
#
# top 2963 with probability of 1.1205673217773438e-05
# ----------3---5-----
# ------7-------------
# --------------------
# ------------------21
# --------------------
# --24----------------
#
# top 2964 with probability of 1.1175870895385742e-05
# ----------3---------
# --------------10----
# ------11------------
# ------------------21
# --------------------
# --24----------------
#
# top 2965 with probability of 1.043081283569336e-05
# ------2-------5-----
# --5-----------------
# --------------------
# ----------17------21
# --------------------
# --------------------
#
# top 2966 with probability of 9.47713851928711e-06
# --------------5-----
# ------7-------------
# --------------------
# ------------------21
# --19------22--------
# --------------------
#
# top 2967 with probability of 9.179115295410156e-06
# ------2-------------
# --5-----------10----
# ------------------16
# ----------17--------
# --------------------
# --------------------
#
# top 2968 with probability of 8.761882781982422e-06
# ------2-------------
# --------------10----
# --------------------
# --14--------------21
# ----------22--------
# --------------------
#
# top 2969 with probability of 8.732080459594727e-06
# --------------5-----
# --5---7-------------
# ------------------16
# --------------------
# ----------22--------
# --------------------
#
# top 2970 with probability of 8.314847946166992e-06
# ------2-------------
# --------------------
# --9-----------14----
# ----------17------21
# --------------------
# --------------------
#
# top 2971 with probability of 8.195638656616211e-06
# --------------------
# ------7-------10----
# --------------------
# ----------17------21
# --19----------------
# --------------------
#
# top 2972 with probability of 8.07642936706543e-06
# ------2-------------
# --------------------
# --------------------
# ----------17--19--21
# --19----------------
# --------------------
#
# top 2973 with probability of 7.420778274536133e-06
# ------2-------------
# --------------------
# --------------14----
# --14------17------21
# --------------------
# --------------------
#
# top 2974 with probability of 7.212162017822266e-06
# --------------5-----
# --------------------
# ------11------------
# ------------------21
# ----------22--------
# --24----------------
#
# top 2975 with probability of 7.152557373046875e-06
# ------2-------------
# ----------8---------
# --------------14----
# ------------------21
# --------------------
# --24----------------
#
# top 2976 with probability of 5.632638931274414e-06
# ----------3---5-----
# --------------------
# ------11----------16
# --------------------
# --------------------
# --24----------------
#
# top 2977 with probability of 5.3942203521728516e-06
# ------2-------------
# --------------------
# --9-----------14----
# ------------------21
# ----------22--------
# --------------------
#
# top 2978 with probability of 5.334615707397461e-06
# ------2-------5-----
# --------------------
# --------------------
# ----------17------21
# --19----------------
# --------------------
#
# top 2979 with probability of 5.304813385009766e-06
# ------2-------5-----
# --------------------
# --9---------------16
# ----------17--------
# --------------------
# --------------------
#
# top 2980 with probability of 5.27501106262207e-06
# ----------3---5-----
# ------7-----------12
# --------------------
# --------------------
# --------------------
# --24----------------
#
# top 2981 with probability of 4.857778549194336e-06
# ------2-------------
# --5-----------------
# --------------14----
# ------------------21
# ----------22--------
# --------------------
#
# top 2982 with probability of 3.4570693969726562e-06
# ------2-------------
# --------------------
# ----------12--14----
# ------------------21
# --------------------
# --24----------------
#
# top 2983 with probability of 2.5033950805664062e-06
# --0---2-------5-----
# --------------------
# ------------------16
# --------------------
# ----------22--------
# --------------------
#
# top 2984 with probability of 2.5033950805664062e-06
# ------2-------5-----
# --------------------
# --9-----------------
# ----------17------21
# --------------------
# --------------------
#
# top 2985 with probability of 2.294778823852539e-06
# --0---2-------5-----
# ------------------12
# --------------------
# ----------17--------
# --------------------
# --------------------
#
# top 2986 with probability of 2.0563602447509766e-06
# ------2-------5-----
# --5-----------------
# ------------------16
# --------------------
# ----------22--------
# --------------------
#
# top 2987 with probability of 1.8775463104248047e-06
# ------2-------------
# --------------10----
# --9-----------------
# ----------17------21
# --------------------
# --------------------
#
# top 2988 with probability of 1.4007091522216797e-06
# ------2-------5-----
# --------------------
# ----------12--------
# ------------------21
# --19----------------
# --------------------
#
# top 2989 with probability of 1.3113021850585938e-06
# ------2-------5-----
# --------------------
# --------------------
# --14--------------21
# ----------22--------
# --------------------
#
# top 2990 with probability of 1.2814998626708984e-06
# ------2-------5-----
# --5-----------------
# --------------------
# ------------------21
# ----------22--------
# --------------------
#
# top 2991 with probability of 1.1026859283447266e-06
# ------2-------------
# --------------10----
# --------------------
# --14------17------21
# --------------------
# --------------------
#
# top 2992 with probability of 1.0132789611816406e-06
# --------------------
# ------7-------10----
# --9-----------------
# ------------------21
# ----------22--------
# --------------------
#
# top 2993 with probability of 1.0132789611816406e-06
# --------------------
# ------7-------------
# --9-----------14----
# ------------------21
# ----------22--------
# --------------------
#
# top 2994 with probability of 9.238719940185547e-07
# ------2-------------
# --5-----------10----
# --------------------
# ------------------21
# ----------22--------
# --------------------
#
# top 2995 with probability of 7.748603820800781e-07
# ------2-------------
# --------------10----
# --9-----------------
# ------------------21
# ----------22--------
# --------------------
#
# top 2996 with probability of 7.152557373046875e-07
# --------------------
# ------7-------10----
# --------------------
# --14--------------21
# ----------22--------
# --------------------
#
# top 2997 with probability of 2.086162567138672e-07
# ------2-------5-----
# --5-----------------
# ------------------16
# ----------17--------
# --------------------
# --------------------
#
# top 2998 with probability of 5.960464477539063e-08
# --------------5-----
# ------7-------------
# --------------------
# --14--------------21
# ----------22--------
# --------------------
#
# top 2999 with probability of 2.9802322387695312e-08
# ------2-------5-----
# --------------------
# --9-----------------
# ------------------21
# ----------22--------
# --------------------
#
# top 3000 with probability of 0.0
# ------2-------5-----
# --------------------
# --------------------
# --14------17------21
# --------------------
# --------------------
